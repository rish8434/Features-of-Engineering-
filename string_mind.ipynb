# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("D:\data set\KAG_conversion_data.csv")

# %%
df.head(5)
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                1143 non-null   int64
#  1   xyz_campaign_id      1143 non-null   int64
#  2   fb_campaign_id       1143 non-null   int64
#  3   age                  1143 non-null   object
#  4   gender               1143 non-null   object
#  5   interest             1143 non-null   int64
#  6   Impressions          1143 non-null   int64
#  7   Clicks               1143 non-null   int64
#  8   Spent                1143 non-null   float64
#  9   Total_Conversion     1143 non-null   int64
#  10  Approved_Conversion  1143 non-null   int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 98.4+ KB

# %%
df.shape
# Out:
# (1143, 11)

# %%
df.describe()
# Out:
#               ad_id  xyz_campaign_id  fb_campaign_id     interest  \
# count  1.143000e+03      1143.000000     1143.000000  1143.000000
# mean   9.872611e+05      1067.382327   133783.989501    32.766404
# std    1.939928e+05       121.629393    20500.308622    26.952131
# min    7.087460e+05       916.000000   103916.000000     2.000000
# 25%    7.776325e+05       936.000000   115716.000000    16.000000
# 50%    1.121185e+06      1178.000000   144549.000000    25.000000
# 75%    1.121804e+06      1178.000000   144657.500000    31.000000
# max    1.314415e+06      1178.000000   179982.000000   114.000000
#
#         Impressions       Clicks        Spent  Total_Conversion  \
# count  1.143000e+03  1143.000000  1143.000000       1143.000000
# mean   1.867321e+05    33.390201    51.360656          2.855643
# std    3.127622e+05    56.892438    86.908418          4.483593
# min    8.700000e+01     0.000000     0.000000          0.000000
# ...

# %%
df.isnull().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                1143 non-null   int64
#  1   xyz_campaign_id      1143 non-null   int64
#  2   fb_campaign_id       1143 non-null   int64
#  3   age                  1143 non-null   object
#  4   gender               1143 non-null   object
#  5   interest             1143 non-null   int64
#  6   Impressions          1143 non-null   int64
#  7   Clicks               1143 non-null   int64
#  8   Spent                1143 non-null   float64
#  9   Total_Conversion     1143 non-null   int64
#  10  Approved_Conversion  1143 non-null   int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 98.4+ KB

# %%
df.nunique()
# Out:
# ad_id                  1143
# xyz_campaign_id           3
# fb_campaign_id          691
# age                       4
# gender                    2
# interest                 40
# Impressions            1130
# Clicks                  183
# Spent                   869
# Total_Conversion         32
# Approved_Conversion      16
# dtype: int64

# %%
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %%
[feature for feature in df.columns if df[feature].dtype=='O']
# Out:
# ['age', 'gender']

# %%
#segrregate numerical and categorical features
numerical_features=[feature for feature in df.columns if df[feature].dtype!='O']
categorical_feature=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
numerical_features
# Out:
# ['ad_id',
#  'xyz_campaign_id',
#  'fb_campaign_id',
#  'interest',
#  'Impressions',
#  'Clicks',
#  'Spent',
#  'Total_Conversion',
#  'Approved_Conversion']

# %%
categorical_feature
# Out:
# ['age', 'gender']

# %%
df["gender"].value_counts()
# Out:
# gender
# M    592
# F    551
# Name: count, dtype: int64

# %%
df['xyz_campaign_id'].value_counts()
# Out:
# xyz_campaign_id
# 1178    625
# 936     464
# 916      54
# Name: count, dtype: int64

# %%
## Aggregate the total score with mean

df['total_score']=(df['interest']+df['Impressions']+df['Clicks'])
df['average']=df['total_score']/3
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1
#
#    total_score      average
# 0         7366  2455.333333
# 1        17879  5959.666667
# 2          713   237.666667
# 3         4288  1429.333333
# ...

# %%
### Explore More Visualization
fig,axis=plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='gender')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='age')
plt.subplot(142)
sns.histplot(data=df[df.gender=='F'],x='average',kde=True,hue='age')
plt.subplot(143)
sns.histplot(data=df[df.gender=='M'],x='average',kde=True,hue='age')
# Out:
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\1278764163.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\1278764163.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\1278764163.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# Insights
#
# . Standard age helps to well use in user.
#
# . Standard age helps to perform well in the use it male and female

# %%
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1
#
#    total_score      average
# 0         7366  2455.333333
# 1        17879  5959.666667
# 2          713   237.666667
# 3         4288  1429.333333
# ...

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='age')
plt.subplot(142)
sns.histplot(data=df[df.gender=='F'],x='average',kde=True,hue='age')
plt.subplot(143)
sns.histplot(data=df[df.gender=='M'],x='average',kde=True,hue='age')
# Out:
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\1278764163.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\1278764163.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\1278764163.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# #####  Insights
# - In general age don't help user perform well in fb.
# - 3rd plot shows that age whose utlize is of associate's fb user  their male child tend to perform
# - 2nd plot we can see there is no effect ofaveg  on female.

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='xyz_campaign_id')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='F'],x='average',kde=True,hue='xyz_campaign_id')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='M'],x='average',kde=True,hue='xyz_campaign_id')
plt.show()
# Out:
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\2554898411.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\2554898411.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\Rishav Kumar\AppData\Local\Temp\ipykernel_12072\2554898411.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)

# %% [markdown]
# ### Insights
# . XYZ_campaign_id  of canpaign_a and compaign_b tends to perform poorly in fb
#
# . XYZ_campaign_id  of canpaign_a and compaign_b tends to perform poorly in fb irrespective of wether they are M and F

# %%
sns.heatmap(df.corr(),annot= True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rk=sns.heatmap(df[["Impressions","Clicks","Spent","Total_Conversion","Approved_Conversion"]].corr(),annot=True ,fmt=".2f", cmap="coolwarm")

# %% [markdown]
# impressions and total conversion are mor correlated with approved conversion than clicks and spent are the matrix

# %% [markdown]
# ## To find unique value

# %%
df["xyz_campaign_id"].unique()
# Out:
# array([ 916,  936, 1178], dtype=int64)

# %% [markdown]
# Here, we see there are 3 different ad campaigns for xyz company.

# %%
df["xyz_campaign_id"].replace({916:"campaign_a",936:"campaign_b",1178:"campaign_c"}, inplace=True)

# %% [markdown]
# here will be replace there name with campaign_a, campaign_b and campaign_c for the better visulization there problem integer value.

# %%
df.head()
# Out:
#     ad_id xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746      campaign_a          103916  30-34      M        15
# 1  708749      campaign_a          103917  30-34      M        16
# 2  708771      campaign_a          103920  30-34      M        20
# 3  708815      campaign_a          103928  30-34      M        28
# 4  708818      campaign_a          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1
#
#    total_score      average
# 0         7366  2455.333333
# 1        17879  5959.666667
# 2          713   237.666667
# 3         4288  1429.333333
# ...

# %%
# count plot on single categorical variable
sns.countplot(x ='xyz_campaign_id', data = df)
# Show the plot
plt.show()

# %% [markdown]
# This shows campaign_c has most number of ads.

# %%
plt.bar(df["xyz_campaign_id"], df["Approved_Conversion"])
plt.ylabel("Approved_Conversion")
plt.title("company vs Approved_Conversion")
plt.show()

# %% [markdown]
# most people bought products in campaign_c.

# %% [markdown]
# ## Age find

# %%
sns.countplot(x='age', data= df)
plt.show()

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
sns.barplot(x=df["xyz_campaign_id"], y=df["Approved_Conversion"], hue=df["age"], data=tips)
# Out:
# <Axes: xlabel='xyz_campaign_id', ylabel='Approved_Conversion'>

# %% [markdown]
# it's intersting to note that in campagin_c and campagin_b , the age group of 30-34 shows more intrest, whereas in campaign_a the age group of 40-44 shows more intrest.

# %% [markdown]
# ## Find Gender

# %%
sns.countplot(x="gender",  data = df)
plt.show()

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
sns.barplot(x=df["xyz_campaign_id"], y=df["Approved_Conversion"], hue=df["gender"], data=tips)
# Out:
# <Axes: xlabel='xyz_campaign_id', ylabel='Approved_Conversion'>

# %% [markdown]
# ## To find the intrest

# %%
fig_dims = (12,5)
fig, ax = plt.subplots(figsize = fig_dims)
sns.countplot(x = "interest", data= df)

plt.show()

# %%
plt.scatter(df["interest"], df["Approved_Conversion"])
plt.title("interest vs. Approved_Conversion")
plt.xlabel("interest")
plt.ylabel("Approved_Conversion")
plt.show()

# %%
a = sns.FacetGrid(df, col="gender")
a.map(plt.scatter, "interest", "Approved_Conversion", alpha=.4)
a.add_legend();

# %%
a= sns.FacetGrid(df, col="age")
a.map(plt.scatter,"interest", "Approved_Conversion", alpha=.4)
a.add_legend();

# %%
plt.hist(df['Approved_Conversion'], bins = 40)
plt.xlabel("Approved_Conversion")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df["Spent"], df["Approved_Conversion"])
plt.title("Spent vs. Approved_Conversion")
plt.xlabel("Spent")
plt.ylabel("Approved_Conversion")
plt.show()

# %% [markdown]
# use of the amount of money spent incrases, no of products bought increase.

# %%
a = sns.FacetGrid(df, col="gender")
a.map(plt.scatter, "Total_Conversion", "Approved_Conversion", alpha=.4)
a.add_legend();

# %%
a = sns.FacetGrid(df, col="age")
a.map(plt.scatter, "Total_Conversion", "Approved_Conversion",alpha=.4)
a.add_legend()

# %%
a=[]
b=[]
c=[]
for i,j,k in zip(df.xyz_campaign_id, df.fb_campaign_id, df.Approved_Conversion):
    if i=="campaign_c":
      a.append(i),b.append(j),c.append(k)

# %%
d={'campaign_name':a, 'fb_campaign_id':b, 'Approved_Conversion':c}     
campaign_c=pd.DataFrame(d)
campaign_c.head()
# Out:
# Empty DataFrame
# Columns: [campaign_name, fb_campaign_id, Approved_Conversion]
# Index: []

# %%
df["xyz_campaign_id"].replace({"campaign_a":916 ,"campaign_b":936 ,"campaign_c":1178}, inplace=True)

# %% [markdown]
# the labels encoding gender and age

# %%
#encoding gender
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
encoder.fit(df["gender"])
df["gender"]=encoder.transform(df["gender"])
print(df["gender"])
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1138    0
# 1139    0
# 1140    0
# 1141    0
# 1142    0
# Name: gender, Length: 1143, dtype: int32

# %%
#encoding age
encoder.fit(df["age"])
df["age"]=encoder.transform(df["age"])
print(df["age"])
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1138    3
# 1139    3
# 1140    3
# 1141    3
# 1142    3
# Name: age, Length: 1143, dtype: int32

# %%
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id  age  gender  interest  \
# 0  708746              916          103916    0       1        15
# 1  708749              916          103917    0       1        16
# 2  708771              916          103920    0       1        20
# 3  708815              916          103928    0       1        28
# 4  708818              916          103928    0       1        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1
#
#    total_score      average
# 0         7366  2455.333333
# 1        17879  5959.666667
# 2          713   237.666667
# 3         4288  1429.333333
# ...

# %% [markdown]
# The Removing Approved_conversion and total_conversion

# %%
x=np.array(df.drop(labels=["Approved_Conversion","Total_Conversion"], axis=1))
y=np.array(df["Total_Conversion"])

# %%
x
# Out:
# array([[7.08746000e+05, 9.16000000e+02, 1.03916000e+05, ...,
#         1.42999995e+00, 7.36600000e+03, 2.45533333e+03],
#        [7.08749000e+05, 9.16000000e+02, 1.03917000e+05, ...,
#         1.82000002e+00, 1.78790000e+04, 5.95966667e+03],
#        [7.08771000e+05, 9.16000000e+02, 1.03920000e+05, ...,
#         0.00000000e+00, 7.13000000e+02, 2.37666667e+02],
#        ...,
#        [1.31441200e+06, 1.17800000e+03, 1.79979000e+05, ...,
#         4.02899995e+01, 1.51670000e+05, 5.05566667e+04],
#        [1.31441400e+06, 1.17800000e+03, 1.79981000e+05, ...,
#         1.98710001e+02, 7.90501000e+05, 2.63500333e+05],
#        [1.31441500e+06, 1.17800000e+03, 1.79982000e+05, ...,
#         1.65609999e+02, 5.13389000e+05, 1.71129667e+05]])

# %%
y
# Out:
# array([2, 2, 1, ..., 2, 8, 5], dtype=int64)

# %%
y= y.reshape(len(y),1)
y
# Out:
# array([[2],
#        [2],
#        [1],
#        ...,
#        [2],
#        [8],
#        [5]], dtype=int64)

# %% [markdown]
# ## Feature Scalling

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x= sc.fit_transform(x)

# %% [markdown]
# ## Train test splitting

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
x_train
# Out:
# array([[-1.43482076, -1.24516442, -1.45519967, ..., -0.59123316,
#         -0.58099051, -0.58099051],
#        [ 0.6927456 ,  0.90986308,  0.5289069 , ...,  0.97143967,
#          0.93310995,  0.93310995],
#        [ 0.69133772,  0.90986308,  0.52666205, ..., -0.42282135,
#         -0.35312324, -0.35312324],
#        ...,
#        [ 1.68709377,  0.90986308,  2.25387959, ...,  1.22814395,
#          1.28782494,  1.28782494],
#        [ 0.69390079,  0.90986308,  0.53071254, ...,  6.4571983 ,
#          6.51437417,  6.51437417],
#        [ 1.68706799,  0.90986308,  2.25363558, ...,  0.80049531,
#          0.69198321,  0.69198321]])

# %%
x_test
# Out:
# array([[-1.23733529, -1.0806585 , -1.11891124, ..., -0.59123316,
#         -0.59466894, -0.59466894],
#        [ 1.68678951,  0.90986308,  2.25100032, ..., -0.29481455,
#         -0.16768885, -0.16768885],
#        [-1.08024012, -1.0806585 , -0.88042024, ..., -0.56107329,
#         -0.55425089, -0.55425089],
#        ...,
#        [-1.3039339 , -1.0806585 , -1.22466324, ..., -0.59123316,
#         -0.5954333 , -0.5954333 ],
#        [-1.08664522, -1.0806585 , -0.89115648, ..., -0.55888612,
#         -0.52828201, -0.52828201],
#        [ 0.6954015 ,  0.90986308,  0.53310379, ...,  0.63968105,
#          0.37506381,  0.37506381]])

# %%
# Column which has string
df.iloc[[122]]
# Out:
#       ad_id  xyz_campaign_id  fb_campaign_id  age  gender  interest  \
# 122  737375              936          109565    2       1        10
#
#      Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 122         1415       0    0.0                 1                    0
#
#      total_score  average
# 122         1425    475.0

# %%
# List out column names to check
df.columns
# Out:
# Index(['ad_id', 'xyz_campaign_id', 'fb_campaign_id', 'age', 'gender',
#        'interest', 'Impressions', 'Clicks', 'Spent', 'Total_Conversion',
#        'Approved_Conversion', 'total_score', 'average'],
#       dtype='object')

# %%
# Spaces were fixed in the column names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['ad_id', 'xyz_campaign_id', 'fb_campaign_id', 'age', 'gender',
#        'interest', 'Impressions', 'Clicks', 'Spent', 'Total_Conversion',
#        'Approved_Conversion', 'total_score', 'average'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                1143 non-null   int64
#  1   xyz_campaign_id      1143 non-null   int64
#  2   fb_campaign_id       1143 non-null   int64
#  3   age                  1143 non-null   int32
#  4   gender               1143 non-null   int32
#  5   interest             1143 non-null   int64
#  6   Impressions          1143 non-null   int64
#  7   Clicks               1143 non-null   int64
#  8   Spent                1143 non-null   float64
#  9   Total_Conversion     1143 non-null   int64
#  10  Approved_Conversion  1143 non-null   int64
#  11  total_score          1143 non-null   int64
#  12  average              1143 non-null   float64
# dtypes: float64(2), int32(2), int64(9)
# memory usage: 107.3 KB

# %%
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id  age  gender  interest  \
# 0  708746              916          103916    0       1        15
# 1  708749              916          103917    0       1        16
# 2  708771              916          103920    0       1        20
# 3  708815              916          103928    0       1        28
# 4  708818              916          103928    0       1        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1
#
#    total_score      average
# 0         7366  2455.333333
# 1        17879  5959.666667
# 2          713   237.666667
# 3         4288  1429.333333
# ...

# %%
ax = sns.boxplot(df['interest'], color= 'orange')

# %%
# Spaces were fixed in the column names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['ad_id', 'xyz_campaign_id', 'fb_campaign_id', 'age', 'gender',
#        'interest', 'Impressions', 'Clicks', 'Spent', 'Total_Conversion',
#        'Approved_Conversion', 'total_score', 'average'],
#       dtype='object')

# %%
dftemp = df.drop(['interest', 'Total_Conversion'], axis=1)
fig = plt.figure(figsize =(12, 6))
ax = dftemp.boxplot()
ax.set_title("Boxplot of Given Dataset")
plt.show()

# %%
df['xyz_campaign_id'].value_counts().plot.pie(y=df['xyz_campaign_id'],figsize=(15,16),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %%
df['interest'].value_counts().plot.pie(y=df['interest'],figsize=(15,16),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Summary

# %% [markdown]
# 1. How to optimize the social ad campaigns for the highest conversion rate possible. (Attain best Reach to Conversion ratios/Click to Conversion ratios)
#
# Ans- Since highest conversion rate was attained in campaign_c, we can consider the factors contributed in this campaign:
#
# * The number of ad counts should be more for better reach.
#
# * The age group of 30-34 should be the main aim.
#
# * People with interest types after 100 should be given more attention
#
# * More the number of times the add is shown i.e. "impression", more approved_conversion rate is achieved.

# %% [markdown]
# 2. Finding the perfect target demographics with the appropriate clickthrough rates
#
# Ans-
# * Women tend to buy the product more often after clicking the ad than men.
# * Also the age group 30 to 34 buy the product more often after clicking the ad

# %% [markdown]
# 3. Understanding the ideal turnaround/decision making time per age group to convert and retarget future social campaigns
#
# Ans-
#
# * Age group 30-34 tend to take less decision making time followed by 35 to 39 and 40-44.
# * Age group 45-49 take the most time to decide.

# %% [markdown]
# 4. Comparing the individual campaign performance so the best creative/campaign can be run again with adjusted audiences.
#
# Ans-
# * clearly campaign_c wins the battle due to highest approved_conversion rate.
# * Also campaign_a does pretty well , considering the number of ads it involves. With less no of ads, it has managed to peform better than campaign_b with large no of ads.
